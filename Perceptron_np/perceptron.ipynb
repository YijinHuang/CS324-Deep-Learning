# %%
import time
import random
import numpy as np
from matplotlib import pyplot as plt
from perceptron import *

# define global value
classes = [1, -1]

# generate data
mean1 = [1, 1]
mean2 = [7, 5]
cov1 = [[1, 0], [0, 1]]
cov2 = [[1, 0], [0, 1]]

data_train, data_test = data_generator(mean1, mean2, cov1, cov2, 160, 40)
plt.scatter(data_train[0][:,0], data_train[0][:,1])
plt.show()
plt.close()

# %%
# train
max_epochs = 100
perceptron = Perceptron(2, max_epochs=max_epochs)
accs, losses = perceptron.train(data_train[0], data_train[1], optimizer='momentum')
# Out:
# epoch 10: loss 1.7583333333333333 val acc 0.3375
# epoch 20: loss 0.008333333333333333 val acc 1.0
# epoch 30: loss 0.008333333333333333 val acc 1.0
# epoch 40: loss 0.0 val acc 1.0
# epoch 50: loss 0.0 val acc 1.0
# epoch 60: loss 0.0 val acc 1.0
# epoch 70: loss 0.0 val acc 1.0
# epoch 80: loss 0.0 val acc 1.0
# epoch 90: loss 0.0 val acc 1.0
# epoch 100: loss 0.0 val acc 1.0
# best val acc 1.0
# load best weight...

# %%
# accuracy curve of validataion data
epochs = [i for i in range(1, int(max_epochs) + 1)]
acc_plot = plt.plot(epochs, accs)
plt.ylim([0, 1.1])
plt.show()
plt.close()

# %%
# loss curve of training data
epochs = [i for i in range(1, int(max_epochs) + 1)]
losses = plt.plot(epochs, losses)
plt.show()
plt.close()

# %%
# accuracy of test data
perceptron.normalization(data_test[0])
acc = perceptron.score(data_test[0], data_test[1])
print('Final test accuracy: {}'.format(acc))
# Out:
# Final test accuracy: 0.9875

# %%
# division line
plt.grid(True)
plt.scatter(data_test[0][:,0], data_test[0][:,1])
line_x = [-1, 0, 1]
slope = -perceptron.w[0]/perceptron.w[1]
line_y = [slope*x for x in line_x]
plt.plot(line_x, line_y, color='r')
plt.show()

# %%
# if mean to close, it will be hard to classify

# generate data
mean1 = [1, 1]
mean2 = [2, 2]
cov1 = [[1, 0], [0, 1]]
cov2 = [[1, 0], [0, 1]]

data_train, data_test = data_generator(mean1, mean2, cov1, cov2, 160, 40)
plt.scatter(data_train[0][:,0], data_train[0][:,1])
plt.show()
plt.close()

# %%
# train
max_epochs = 100
perceptron = Perceptron(2, max_epochs=max_epochs)
accs, losses = perceptron.train(data_train[0], data_train[1], optimizer='momentum')
# Out:
# epoch 10: loss 0.7416666666666667 val acc 0.5625
# epoch 20: loss 0.6833333333333333 val acc 0.7375
# epoch 30: loss 0.65 val acc 0.275
# epoch 40: loss 0.7666666666666667 val acc 0.7125
# epoch 50: loss 0.6333333333333333 val acc 0.675
# epoch 60: loss 0.7583333333333333 val acc 0.7125
# epoch 70: loss 0.6166666666666667 val acc 0.4875
# epoch 80: loss 0.6916666666666667 val acc 0.6625
# epoch 90: loss 0.6416666666666667 val acc 0.675
# epoch 100: loss 0.6583333333333333 val acc 0.6875
# best val acc 0.7375
# load best weight...

# %%
# accuracy curve of validataion data
acc_plot = plt.plot(epochs, accs)
plt.ylim([0, 1.1])
plt.show()
plt.close()

# %%
# accuracy of test data
perceptron.normalization(data_test[0])
acc = perceptron.score(data_test[0], data_test[1])
print('Final test accuracy: {}'.format(acc))
# Out:
# Final test accuracy: 0.775

# %%
# division line
plt.grid(True)
plt.scatter(data_test[0][:,0], data_test[0][:,1])
line_x = [-1, 0, 1]
slope = -perceptron.w[0]/perceptron.w[1]
line_y = [slope*x for x in line_x]
plt.plot(line_x, line_y, color='r')
plt.show()
